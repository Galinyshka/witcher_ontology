# %%
from parser import parse_characters_list, parse_character, get_html
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
from parser import parse_characters_list
import requests
from bs4 import BeautifulSoup
import pandas as pd

df = pd.read_csv('data/books.csv')
books = list(df.title)
characters = parse_characters_list(books)
pd.DataFrame(characters, columns=['character']).to_csv('data/characters.csv', index=False)

# %%
from parser import parse_character
import requests
from bs4 import BeautifulSoup
import pandas as pd

df = pd.read_csv('data/characters.csv')
characters = list(df.character)
df_parsed = pd.DataFrame(parse_character(characters))
df_parsed.to_csv(f"data/characters_info.csv", index=False, encoding="utf-8")
# Out:
# Redirected from 'Cahir' → 'Cahir Mawr Dyffryn aep Ceallach'
# Redirected from 'Vilgefortz' → 'Vilgefortz of Roggeveen'
# Redirected from 'Yennefer' → 'Yennefer of Vengerberg'
# Redirected from 'Addario Bach' → 'Addarion Bach'

# %%
df = pd.read_csv("data/characters_info.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   character      64 non-null     object
#  1   full name      64 non-null     object
#  2   born           10 non-null     float64
#  3   nationality    34 non-null     object
#  4   hair_color     41 non-null     object
#  5   eye_color      31 non-null     object
#  6   race           60 non-null     object
#  7   gender         62 non-null     object
#  8   status         29 non-null     object
#  9   titles         22 non-null     object
#  10  profession     52 non-null     object
#  11  affiliations   44 non-null     object
#  12  abilities      30 non-null     object
#  13  appears_books  64 non-null     object
#  14  appears_games  38 non-null     object
# dtypes: float64(1), object(14)
# memory usage: 7.6+ KB

# %%
r = pd.DataFrame(parse_character(["Rience"]))
r.to_csv(f"data/rience_info.csv", index=False, encoding="utf-8")

# %%
unique_aff = set()
import ast

df['affiliations'] = df['affiliations'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) and x.startswith('[') else x )
for item in df['affiliations']:
    if isinstance(item, list): 
        unique_aff.update(item)

print(len(unique_aff))
print(unique_aff)
# Out:
# 48
# {'Druids of Kovirian Circle', 'Belohun', 'Mahakam Volunteer Army', 'Lytta Neyd', 'Sigismund Dijkstra', 'King  Vizimir II of Redania', 'Lodge of Sorceresses', "Yarpen Zigrin's company", 'Codringher and Fenn', 'Oxenfurt Academy', 'Council of Wizards', 'King  Demavend III of Aedirn', "Skellen's gang", 'Aelirenn', 'Giancardi Bank', 'Syndicate', 'King  Belohun of Kerack', 'School of the Wolf', 'Temple of Melitele', "Geralt's company", 'Nilfgaardian Military Intelligence', 'Vilgefortz', 'King  Henselt of Kaedwen', 'Rissberg', 'Bailiff of Gors Velen', 'Brotherhood of Sorcerers', 'Aedirnian Special Forces', 'Aedirnian Special Service', 'King  Foltest of Temeria', 'Redanian Secret Service', 'Nilfgaardian Secret Service', "Sigismund's Bathhouse", 'Regency Council', "Lyrian-Rivian Army White Queen's corps", 'Temerian Royal Council', 'Wolf School', 'Kaedwenian Secret Service', 'Order of the Flaming Rose', 'University of Oxenfurt', 'Ban Ard Academy', 'Chapter of the Gift and the Art', 'Luitpold Lindenbrog', 'Big Four', 'School of the Griffin', "Shani's Clinic", 'Demavend III', 'School of the Cat', "Melitele 's clergy"}

# %%
for i in range(63):
    print(i, df['character'][i], df['affiliations'][i])
# Out:
# 0 Cahir ['Nilfgaardian Secret Service', "Geralt's company"]
# 1 Calanthe nan
# 2 Ciri nan
# 3 Coën ['School of the Griffin']
# 4 Dandelion ["Geralt's company", 'Redanian Secret Service', 'University of Oxenfurt']
# 5 Demavend III nan
# 6 Emhyr var Emreis nan
# 7 Eskel ['School of the Wolf']
# 8 Foltest nan
# 9 Geralt of Rivia ['Wolf School']
# 10 Jarre ['Temple of Melitele']
# 11 Lambert ['School of the Wolf']
# 12 Michelet brothers nan
# 13 Meve ["Lyrian-Rivian Army White Queen's corps"]
# 14 Myhrman nan
# 15 Nenneke ["Melitele 's clergy"]
# 16 Ori Reuven ['Sigismund Dijkstra', 'Redanian Secret Service']
# 17 Philippa Eilhart ['King  Vizimir II of Redania', 'Lodge of Sorceresses', 'Brotherhood of Sorcerers']
# 18 Rayla ['Aedirnian Special Forces', 'Order of the Flaming Rose']
# 19 Rience ['Vilgefortz', 'Skellen's gang', 'Ban Ard Academy', 'Kaedwenian Secret Service', 'Nilfgaardian Military Intelligence']
# 20 Shani ['Oxenfurt Academy', "Shani's Clinic"]
# 21 Sigismund Dijkstra ['Redanian Secret Service', 'Regency Council', "Sigismund's Bathhouse", 'Big Four', 'Syndicate']
# 22 Tissaia de Vries ['Brotherhood of Sorcerers']
# 23 Triss Merigold ['King  Foltest of Temeria', 'Lodge of Sorceresses', 'Temerian Royal Council']
# 24 Vesemir ['School of the Wolf']
# 25 Vilgefortz ['Druids of Kovirian Circle', 'Brotherhood of Sorcerers']
# 26 Vizimir II nan
# 27 Yarpen Zigrin ["Yarpen Zigrin's company", 'Mahakam Volunteer Army']
# 28 Yennefer of Vengerberg ['Lodge of Sorceresses', 'Demavend III', 'Brotherhood of Sorcerers', 'Council of Wizards']
# 29 Aplegatt ['Demavend III', 'Aedirnian Special Service']
# 30 Artaud Terranova ['Brotherhood of Sorcerers', 'Chapter of the Gift and the Art']
# 31 Codringher ['Codringher and Fenn']
# 32 Fabio Sachs ['Giancardi Bank']
# 33 Francesca Findabair ['Lodge of Sorceresses', 'Brotherhood of Sorcerers', 'Chapter of the Gift and the Art', 'Aelirenn']
# 34 Jacob Fenn ['Codringher and Fenn']
# 35 Keira Metz ['King  Foltest of Temeria', 'Lodge of Sorceresses', 'Temerian Royal Council']
# 36 Lydia van Bredevoort ['Vilgefortz', 'Brotherhood of Sorcerers']
# 37 Margarita Laux-Antille ['Lodge of Sorceresses', 'Brotherhood of Sorcerers']
# 38 Molnar Giancardi ['Giancardi Bank']
# 39 Radcliffe ['Brotherhood of Sorcerers', 'Council of Wizards', 'King  Demavend III of Aedirn']
# 40 Rats nan
# 41 Sabrina Glevissig ['King  Henselt of Kaedwen', 'Lodge of Sorceresses']
# 42 Yennefer ['Lodge of Sorceresses', 'Demavend III', 'Brotherhood of Sorcerers', 'Council of Wizards']
# 43 Lytta Neyd ['King  Belohun of Kerack']
# 44 Belohun nan
# 45 Sorel Degerlund ['Rissberg']
# 46 Ortolan ['Rissberg']
# 47 Mozaïk ['Lytta Neyd']
# 48 Ferrant de Lettenhove ['Belohun']
# 49 Addario Bach nan
# 50 Pyral Pratt nan
# 51 Brehen ['School of the Cat']
# 52 Egmund nan
# 53 Algernon Guincamp ['Rissberg']
# 54 Frans Torquil ['Bailiff of Gors Velen']
# 55 Nimue verch Wledyr ap Gwyn nan
# 56 Antea Derris nan
# 57 Tiziana Frevi nan
# 58 Artamon of Asguth nan
# 59 Cervia Herrada de Graffiacane nan
# 60 Elena Fiachra de Mersault ['Luitpold Lindenbrog']
# 61 Luitpold Lindenbrog nan
# 62 Preston Holt nan
