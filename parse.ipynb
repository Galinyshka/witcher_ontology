# %%
import requests
from bs4 import BeautifulSoup

url = "https://witcher.fandom.com/api.php"
params = {
    "action": "parse",
    "page": "Geralt of Rivia",
    "prop": "text",
    "format": "json"
}

r = requests.get(url, params=params)
data = r.json()

html = data["parse"]["text"]["*"]

soup = BeautifulSoup(html, "html.parser")

# %% [markdown]
# # Для списков!!!

# %%
from bs4 import BeautifulSoup

html = '''<div class="pi-data-value pi-font">Heiress to the throne of Cintra<br>Heiress to Inis <a href="/wiki/Ard_Skellig" title="Ard Skellig">Ard Skellig</a> and Inis <a href="/wiki/An_Skellig" title="An Skellig">An Skellig</a><br><a href="/wiki/Princess" class="mw-redirect" title="Princess">Princess</a> of <a href="/wiki/Brugge" title="Brugge">Brugge</a> <small>(claimant)</small><br><a href="/wiki/Duchess" class="mw-redirect" title="Duchess">Duchess</a> of <a href="/wiki/Sodden" title="Sodden">Sodden</a> <small>(claimant)</small><br>Suzerain of <a href="/wiki/Attre" title="Attre">Attre</a> and <a href="/wiki/Abb_Yarra" title="Abb Yarra">Abb Yarra</a> <small>(claimant, given to her <a href="/wiki/False_Ciri" class="mw-redirect" title="False Ciri">double</a>)</small></div>'''
html = '''<div class="pi-item pi-data pi-item-spacing pi-border-color" data-source="abilities">
	
		<h3 class="pi-data-label pi-secondary-font">Abilities</h3>
	
	<div class="pi-data-value pi-font">Superhuman abilities<br>Swordsmanship<br><a href="/wiki/Alchemy" title="Alchemy">Alchemy</a><br><a href="/wiki/Signs" class="mw-redirect" title="Signs">Signs</a></div>
</div>'''
soup = BeautifulSoup(html, "html.parser")
div = soup.find("div", class_="pi-data-value")

# Убираем ненужные теги (small, sup)
for tag in div.find_all(["small", "sup"]):
    tag.decompose()

result = []
current = []

# Обходим всех детей, включая текст и теги
for elem in div.children:
    if getattr(elem, "name", None) == "br":
        # закончили один блок
        text = " ".join(current).strip()
        if text:
            result.append(text)
        current = []
    else:
        # собираем текст текущего блока
        if hasattr(elem, "get_text"):
            current.append(elem.get_text(" ", strip=True))
        elif isinstance(elem, str):
            current.append(elem.strip())

# добавляем последний блок
if current:
    text = " ".join(current).strip()
    if text:
        result.append(text)

# объединяем через запятую
final = ", ".join(result)
print(final)
# Out:
# Superhuman abilities, Swordsmanship, Alchemy, Signs

# %%
from parser import parse_character
import requests
from bs4 import BeautifulSoup

url = "https://witcher.fandom.com/api.php"
params = {
    "action": "parse",
    "page": "Calanthe",
    "prop": "text",
    "format": "json"
}

r = requests.get(url, params=params)
data = r.json()

html = data["parse"]["text"]["*"]

soup = BeautifulSoup(html, "html.parser")

result = parse_character(soup)

# %%
result
# Out:
# {'name': 'Calanthe Fiona Riannon',
#  'born': 1217,
#  'nationality': 'Cintra',
#  'hair_color': 'Ashen grey',
#  'eye_color': 'Emerald green',
#  'race': 'Human',
#  'gender': 'Female',
#  'title': ['Queen of Cintra'],
#  'profession': None,
#  'affiliation': None,
#  'abilities': None,
#  'book_appear': ['The Last Wish',
#   'Sword of Destiny',
#   'Blood of Elves',
#   'Time of Contempt',
#   'Baptism of Fire',
#   'The Tower of the Swallow',
#   'The Lady of the Lake'],
#  'game_appear': ['Gwent: The Witcher Card Game']}

# %%
print(soup.find("aside", class_="portable-infobox"))
# Out:
# <aside class="portable-infobox pi-background pi-border-color pi-theme-wikia pi-layout-default" role="region">
# <h2 class="pi-item pi-item-spacing pi-title pi-secondary-background" data-source="name">Calanthe Fiona Riannon</h2>
# <figure class="pi-item pi-image" data-source="image">
# <a class="image image-thumbnail" href="https://static.wikia.nocookie.net/witcher/images/e/e6/Calanthe_by_Jana_Komarkov%C3%A1.png/revision/latest?cb=20180327012119" title="Calanthe by Jana Komarková">
# <img alt="Calanthe by Jana Komarková" class="pi-image-thumbnail" data-image-key="Calanthe_by_Jana_Komarkov%C3%A1.png" data-image-name="Calanthe by Jana Komarková.png" data-relevant="1" height="500" src="https://static.wikia.nocookie.net/witcher/images/e/e6/Calanthe_by_Jana_Komarkov%C3%A1.png/revision/latest/scale-to-width-down/268?cb=20180327012119" srcset="https://static.wikia.nocookie.net/witcher/images/e/e6/Calanthe_by_Jana_Komarkov%C3%A1.png/revision/latest/scale-to-width-down/268?cb=20180327012119 1x, https://static.wikia.nocookie.net/witcher/images/e/e6/Calanthe_by_Jana_Komarkov%C3%A1.png/revision/latest?cb=20180327012119 2x" width="242"/>
# </a>
# </figure>
# <section class="pi-item pi-group pi-border-color">
# <h2 class="pi-item pi-header pi-secondary-font pi-item-spacing pi-secondary-background">Basic Information</h2>
# <div class="pi-item pi-data pi-item-spacing pi-border-color" data-source="aka">
# <h3 class="pi-data-label pi-secondary-font">Alias(es)</h3>
# <div class="pi-data-value pi-font">Ard Rhena<br/><p>Lioness of Cintra<br/>Modron</p></div>
# </div>
# <div class="pi-item pi-data pi-item-spacing pi-border-color" data-source="born">
# <h3 class="pi-data-label pi-secondary-font">Born</h3>
# <div class="pi-data-value pi-font"><a href="/wiki/Timeline#1217" title="Timeline">1217</a></div>
# </div>
# <div class="pi-item pi-data pi-item-spacing pi-border-color" data-source="status">
# <h3 class="pi-data-label pi-secondary-font">Status</h3>
# <div class="pi-data-value pi-font">Deceased <small>(jumped to her death during the <a href="/wiki/Slaughter_of_Cintra" title="Slaughter of Cintra">Slaughter of Cintra</a>)</small></div>
# </div>
# <div class="pi-item pi-data pi-item-spacing pi-border-color" data-source="nationality">
# <h3 class="pi-data-label pi-secondary-font">Nationality</h3>
# <div class="pi-data-value pi-font"><span typeof="mw:File"><a href="/wiki/Cintra" title="Cintra"><img class="mw-file-element" data-image-key="Flag_Cintra1.svg" data-image-name="Flag Cintra1.svg" data-relevant="1" decoding="async" height="31" loading="lazy" src="https://static.wikia.nocookie.net/witcher/images/e/e8/Flag_Cintra1.svg/revision/latest/scale-to-width-down/50?cb=20190718232241" width="50"/></a></span></div>
# </div>
# <div class="pi-item pi-data pi-item-spacing pi-border-color" data-source="coa">
# <h3 class="pi-data-label pi-secondary-font">Coat of arms</h3>
# <div class="pi-data-value pi-font"><figure class="mw-halign-left" typeof="mw:File"><a class="mw-file-description image" href="https://static.wikia.nocookie.net/witcher/images/6/68/COA_Cintra2.svg/revision/latest?cb=20190119223809"><img class="mw-file-element" data-image-key="COA_Cintra2.svg" data-image-name="COA Cintra2.svg" data-relevant="1" decoding="async" height="60" loading="lazy" src="https://static.wikia.nocookie.net/witcher/images/6/68/COA_Cintra2.svg/revision/latest/scale-to-width-down/50?cb=20190119223809" width="50"/></a><figcaption></figcaption></figure></div>
# </div>
# </section>
# <section class="pi-item pi-group pi-border-color">
# <h2 class="pi-item pi-header pi-secondary-font pi-item-spacing pi-secondary-background">Physical Information</h2>
# <div class="pi-item pi-data pi-item-spacing pi-border-color" data-source="hair_color">
# <h3 class="pi-data-label pi-secondary-font">Hair color</h3>
# <div class="pi-data-value pi-font">Ashen grey</div>
# </div>
# <div class="pi-item pi-data pi-item-spacing pi-border-color" data-source="eye_color">
# <h3 class="pi-data-label pi-secondary-font">Eye color</h3>
# <div class="pi-data-value pi-font">Emerald green</div>
# </div>
# <div class="pi-item pi-data pi-item-spacing pi-border-color" data-source="race">
# <h3 class="pi-data-label pi-secondary-font">Race</h3>
# <div class="pi-data-value pi-font"><a href="/wiki/Human" title="Human">Human</a></div>
# </div>
# <div class="pi-item pi-data pi-item-spacing pi-border-color" data-source="gender">
# <h3 class="pi-data-label pi-secondary-font">Gender</h3>
# <div class="pi-data-value pi-font">Female</div>
# </div>
# </section>
# <section class="pi-item pi-group pi-border-color">
# <h2 class="pi-item pi-header pi-secondary-font pi-item-spacing pi-secondary-background">Personal Information</h2>
# <div class="pi-item pi-data pi-item-spacing pi-border-color" data-source="titles">
# <h3 class="pi-data-label pi-secondary-font">Title(s)</h3>
# <div class="pi-data-value pi-font"><a class="mw-redirect" href="/wiki/Queen" title="Queen">Queen</a> of <a href="/wiki/Cintra" title="Cintra">Cintra</a></div>
# </div>
# </section>
# <section class="pi-item pi-group pi-border-color">
# <h2 class="pi-item pi-header pi-secondary-font pi-item-spacing pi-secondary-background">Family</h2>
# <div class="pi-item pi-data pi-item-spacing pi-border-color" data-source="family">
# <h3 class="pi-data-label pi-secondary-font">Family</h3>
# <div class="pi-data-value pi-font"><a href="/wiki/House_of_Raven" title="House of Raven">House of Raven</a></div>
# </div>
# <div class="pi-item pi-data pi-item-spacing pi-border-color" data-source="parents">
# <h3 class="pi-data-label pi-secondary-font">Parent(s)</h3>
# <div class="pi-data-value pi-font"><a href="/wiki/Adalia" title="Adalia">Adalia</a> <small>(mother)</small><br/><a href="/wiki/Dagorad" title="Dagorad">Dagorad</a> <small>(father)</small></div>
# </div>
# <div class="pi-item pi-data pi-item-spacing pi-border-color" data-source="partner">
# <h3 class="pi-data-label pi-secondary-font">Partner(s)</h3>
# <div class="pi-data-value pi-font"><a href="/wiki/Roegner_of_Ebbing" title="Roegner of Ebbing">Roegner of Ebbing</a> <small>(first husband, deceased)</small><br/><a href="/wiki/Eist_Tuirseach" title="Eist Tuirseach">Eist Tuirseach</a> <small>(second husband)</small></div>
# </div>
# <div class="pi-item pi-data pi-item-spacing pi-border-color" data-source="children">
# <h3 class="pi-data-label pi-secondary-font">Child(ren)</h3>
# <div class="pi-data-value pi-font"><a href="/wiki/Pavetta" title="Pavetta">Pavetta</a> <small>(daughter)</small></div>
# </div>
# <div class="pi-item pi-data pi-item-spacing pi-border-color" data-source="relative">
# <h3 class="pi-data-label pi-secondary-font">Relative(s)</h3>
# <div class="pi-data-value pi-font"><a href="/wiki/Ciri" title="Ciri">Ciri</a> <small>(granddaughter)</small><br/><a href="/wiki/Crach_an_Craite" title="Crach an Craite">Crach an Craite</a> <small>(nephew)</small><br/><a href="/wiki/Meve" title="Meve">Meve</a> <small>(distant cousin)</small></div>
# </div>
# </section>
# <section class="pi-item pi-group pi-border-color pi-collapse pi-collapse-closed">
# <h2 class="pi-item pi-header pi-secondary-font pi-item-spacing pi-secondary-background">Appearance(s)</h2>
# <div class="pi-item pi-data pi-item-spacing pi-border-color" data-source="lookalike">
# <h3 class="pi-data-label pi-secondary-font">Actor</h3>
# <div class="pi-data-value pi-font"><a class="external text" href="https://www.imdb.com/name/nm0936587/" rel="nofollow noreferrer noopener" target="_blank">Ewa Wiśniewska</a> <small>(<i><a href="/wiki/The_Hexer" title="The Hexer">The Hexer</a></i>)</small><br/><a href="/wiki/Jodhi_May" title="Jodhi May">Jodhi May</a> <small>(<a href="/wiki/The_Witcher_(TV_series)" title="The Witcher (TV series)">Netflix's <i>The Witcher</i></a>)</small></div>
# </div>
# <div class="pi-item pi-data pi-item-spacing pi-border-color" data-source="appears_books">
# <h3 class="pi-data-label pi-secondary-font">Books</h3>
# <div class="pi-data-value pi-font"><i><a href="/wiki/The_Last_Wish" title="The Last Wish">The Last Wish</a></i><br/><i><a href="/wiki/Sword_of_Destiny" title="Sword of Destiny">Sword of Destiny</a></i><br/><i><a href="/wiki/Blood_of_Elves" title="Blood of Elves">Blood of Elves</a></i><br/><i><a href="/wiki/Time_of_Contempt" title="Time of Contempt">Time of Contempt</a></i> <small>(mentioned)</small><br/><i><a href="/wiki/Baptism_of_Fire" title="Baptism of Fire">Baptism of Fire</a></i><br/><i><a href="/wiki/The_Tower_of_the_Swallow" title="The Tower of the Swallow">The Tower of the Swallow</a></i><br/><i><a href="/wiki/The_Lady_of_the_Lake" title="The Lady of the Lake">The Lady of the Lake</a></i></div>
# </div>
# <div class="pi-item pi-data pi-item-spacing pi-border-color" data-source="appears_games">
# <h3 class="pi-data-label pi-secondary-font">Games</h3>
# <div class="pi-data-value pi-font"><i><a href="/wiki/Gwent:_The_Witcher_Card_Game" title="Gwent: The Witcher Card Game">Gwent: The Witcher Card Game</a></i></div>
# </div>
# <div class="pi-item pi-data pi-item-spacing pi-border-color" data-source="appears_tv">
# <h3 class="pi-data-label pi-secondary-font">TV/Film</h3>
# <div class="pi-data-value pi-font"><i><a href="/wiki/The_Hexer" title="The Hexer">The Hexer</a></i> TV series<br/><a href="/wiki/The_Witcher_(TV_series)" title="The Witcher (TV series)">Netflix's <i>The Witcher</i></a></div>
# </div>
# </section>
# </aside>
